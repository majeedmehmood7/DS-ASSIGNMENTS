# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"Hometask.csv")
df
# Out:
#     Population  Year
# 0          130  1950
# 1          135  1960
# 2          139  1970
# 3          140  1980
# 4          140  1990
# 5          146  2000
# 6          150  2010
# 7          162  2020
# 8          169  2025
# 9          170  2030
# 10         172  2035
# 11         187  2040
# 12         192  2045
# 13         198  2050

# %%
plt.scatter(x= df.Population, y = df.Year)
plt.xlabel("Population")
plt.ylabel("year")
plt.title("Pakistan Populations")
plt.show()

# %%
X = df.drop("Population", axis = "columns")
Y = df.drop("Year", axis = "columns")
print("Shape of X = ",X.shape)
print("shape of y ",Y.shape)
# Out:
# Shape of X =  (14, 1)
# shape of y  (14, 1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test ,Y_train , Y_test = train_test_split(X,Y , test_size = 0.2, random_state = 51)
print("Shape of X_train = ", X_train.shape)
print("Shape of Y_train = ", Y_train.shape)
print("Shape of X_Test = ", X_test.shape)
print("Shape of Y_Test = ", Y_test.shape)
# Out:
# Shape of X_train =  (11, 1)
# Shape of Y_train =  (11, 1)
# Shape of X_Test =  (3, 1)
# Shape of Y_Test =  (3, 1)

# %%
from sklearn.linear_model import LinearRegression
Ir = LinearRegression()
Ir.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(X_test,Y_test)
plt.plot(X_train,Ir.predict(X_train),color = 'r')

# %%
Ir.intercept_
# Out:
# array([-1163.50856233])

# %%
Ir.coef_
# Out:
# array([[0.65886101]])

# %%
m = 1.63164261
c = -3088.70264424
y = m * 2025+c
y
# Out:
# 215.37364101000003

# %%
tmp_new = float(input("Enter the hours: "))
Ir.predict([[tmp_new]])
# Out:
# Enter the hours: 2025
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"
# array([[170.68498606]])

# %%
m = 1.63164261
c = -3088.70264424
y = m * 2030+c
y
# Out:
# 223.53185406000011

# %%
tmp_new = float(input("Enter the hours: "))
Ir.predict([[tmp_new]])
# Out:
# Enter the hours: 2030
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"
# array([[173.97929112]])

# %%
m = 1.63164261
c = -3088.70264424
y = m * 2040+c
y
# Out:
# 239.8482801600003

# %%
tmp_new = float(input("Enter the hours: "))
Ir.predict([[tmp_new]])
# Out:
# Enter the hours: 2040
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"
# array([[180.56790123]])

# %%
y_pred = Ir.predict(X_test)
y_pred

pd.DataFrame(np.c_[Y_test, y_pred], columns = ["Population","Population Prediction"] )
# Out:
#    Population  Population Prediction
# 0       135.0             125.633294
# 1       140.0             146.844648
# 2       215.0             207.215424
# 3       139.0             133.791507
# 4       170.0             179.477500
