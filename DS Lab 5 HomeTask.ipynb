# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the global temperature dataset
global_temp = pd.read_csv('https://raw.githubusercontent.com/jbrownlee/Datasets/master/monthly-mean-temp.csv')
# Keep only the 'Source' and 'Mean' columns
global_temp = global_temp[['Source', 'Mean']]
# Rename the columns to 'year' and 'temperature'
global_temp.columns = ['year', 'temperature']
# Keep only the rows where 'Source' is 'GCAG'
global_temp = global_temp[global_temp['year'].str.startswith('GCAG')]

# Load the atmospheric carbon dioxide dataset
atm_co2 = pd.read_csv('https://raw.githubusercontent.com/jbrownlee/Datasets/master/monthly-in-situ-ncdc/co2-raw-monthly.csv')
# Keep only the 'year' and 'decimal date' columns
atm_co2 = atm_co2[['year', 'decimal date']]
# Rename the columns to 'year' and 'co2'
atm_co2.columns = ['year', 'co2']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-adfa8e5dd7df> in <cell line: 7>()
#       5 global_temp = pd.read_csv('https://raw.githubusercontent.com/jbrownlee/Datasets/master/monthly-mean-temp.csv')
#       6 # Keep only the 'Source' and 'Mean' columns
# ----> 7 global_temp = global_temp[['Source', 'Mean']]
#       8 # Rename the columns to 'year' and 'temperature'
#       9 global_temp.columns = ['year', 'temperature']
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3811             if is_iterator(key):
#    3812                 key = list(key)
# -> 3813             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3814
#    3815         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
# ...

# %%
# Load global temperature data
temp_url = 'https://data.giss.nasa.gov/gistemp/tabledata_v4/GLB.Ts+dSST.csv'
temp_df = pd.read_csv(temp_url, skiprows=1)
temp_df
# Out:
#      Year   Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct   Nov  \
# 0    1880 -0.18 -0.24  -.08  -.16  -.10  -.21  -.18  -.10  -.14  -.23  -.21
# 1    1881 -0.19 -0.14   .04   .05   .06  -.18   .01  -.03  -.15  -.21  -.18
# 2    1882  0.16  0.14   .05  -.16  -.14  -.22  -.16  -.08  -.15  -.23  -.17
# 3    1883 -0.29 -0.36  -.12  -.18  -.18  -.07  -.07  -.14  -.22  -.11  -.24
# 4    1884 -0.13 -0.08  -.36  -.39  -.33  -.35  -.30  -.28  -.27  -.24  -.33
# ..    ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 139  2019  0.93  0.95  1.16  1.01   .85   .91   .94   .95   .93  1.01   .99
# 140  2020  1.17  1.24  1.17  1.13  1.02   .92   .90   .87   .99   .89  1.10
# 141  2021  0.81  0.64   .88   .75   .78   .84   .92   .81   .92  1.00   .93
# 142  2022  0.91  0.89  1.05   .83   .84   .92   .93   .95   .89   .97   .73
# 143  2023  0.86  0.97   ***   ***   ***   ***   ***   ***   ***   ***   ***
#
#       Dec   J-D   D-N   DJF   MAM   JJA   SON
# ...

# %%
# Rename columns
temp_df = temp_df.rename(columns={'Year': 'year', 'J-D': 'temperature'})

# %%
# Keep only relevant columns
temp_df = temp_df[['year', 'temperature']]

# %%
# Convert temperature to Celsius
temp_df['temperature'] = (temp_df['temperature'] - 32) * 5/9
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.9/dist-packages/pandas/core/ops/array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     164     try:
# --> 165         result = func(left, right)
#     166     except TypeError:
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/computation/expressions.py in evaluate(op, a, b, use_numexpr)
#     240             # error: "None" not callable
# --> 241             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     242     return _evaluate_standard(op, op_str, a, b)
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     128     if result is None:
# --> 129         result = _evaluate_standard(op, op_str, a, b)
#     130
#
# ...
