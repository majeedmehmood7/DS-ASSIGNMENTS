# %%
# !pip install nltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
pip install -U nltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import nltk

# %%
from nltk.tokenize import word_tokenize
nltk.download('punkt')

sentence = "Books are on the table"

words = word_tokenize(sentence)
print(words)
# Out:
# ['Books', 'are', 'on', 'the', 'table']
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
sentence = "Books are on the table."
sentence = sentence.lower()
print(sentence)
# Out:
# books are on the table.

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 
  
sentence = "Machine Learning is cool!"
  
stop_words = set(stopwords.words('english')) 
word_tokens = word_tokenize(sentence)
  
filtered_sentence = [w for w in word_tokens if not w in stop_words] 
print(filtered_sentence)
# Out:
# ['Machine', 'Learning', 'cool', '!']
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
import nltk
from nltk.stem import PorterStemmer
ps = PorterStemmer()

sentence = "Machine Learning is cool"
print(type(sentence))
for word in sentence.split():
  print(ps.stem(word))
# Out:
# <class 'str'>
# machin
# learn
# is
# cool

# %%
import nltk
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer 

lemmatizer = WordNetLemmatizer()

print(lemmatizer.lemmatize("Machine", pos='n'))
# pos: parts of speech tag, verb
print(lemmatizer.lemmatize("caring", pos='v'))
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# Machine
# care

# %%
from nltk import ngrams
sentence = "This is my sentence and I want to ngramize it."
n = 2
n1_grams = ngrams(sentence.split(), n)
for grams in n1_grams:
    print(grams)
# Out:
# ('This', 'is')
# ('is', 'my')
# ('my', 'sentence')
# ('sentence', 'and')
# ('and', 'I')
# ('I', 'want')
# ('want', 'to')
# ('to', 'ngramize')
# ('ngramize', 'it.')

# %% [markdown]
# # Project#1 --> using sample corpus dataset provided by NLTK

# %%
# Importing module
import nltk

# %%
# Sample corpus.
from nltk.corpus import inaugural
nltk.download('inaugural')
corpus = inaugural.raw('1789-Washington.txt')
#print(corpus)
print(inaugural.fileids())  # list of all available inaugural address texts
print(corpus[:1000])

# %%
from nltk.tokenize import word_tokenize,sent_tokenize
sents = nltk.sent_tokenize(corpus)
print("The number of sentences is", len(sents))
words = nltk.word_tokenize(corpus)
print("The number of tokens is", len(words))
average_tokens = round(len(words)/len(sents))
print("The average number of tokens per sentence is",average_tokens)
unique_tokens = set(words)
print("The number of unique tokens are", len(unique_tokens))

# %%
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
final_tokens = []
for each in words:
 if each not in stop_words:
    final_tokens.append(each)
print("The number of total tokens after removing stopwords are", len((final_tokens)))

# %%
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()

for w in final_tokens:
    print(w, " : ", ps.stem(w))

# %%
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet') 
lemmatizer = WordNetLemmatizer()   #an instance of Word Net Lemmatizer
# pos: parts of speech tag, verb
print(lemmatizer.lemmatize("Fellow-Citizens", pos='n'))
print(lemmatizer.lemmatize("Senate", pos='n'))
print(lemmatizer.lemmatize("House ", pos='n'))
print(lemmatizer.lemmatize("Representatives ", pos='n'))

# %%
import nltk
from nltk.util import ngrams

# Load the text data
nltk.download('inaugural')
corpus = nltk.corpus.inaugural.raw('1789-Washington.txt')

# Tokenize the text into words
words = nltk.word_tokenize(corpus)

# Generate bigrams (n=2)
bigrams = list(ngrams(words, 2))

# Print the first 10 bigrams
print(bigrams[:10])
# Out:
# [('Fellow-Citizens', 'of'), ('of', 'the'), ('the', 'Senate'), ('Senate', 'and'), ('and', 'of'), ('of', 'the'), ('the', 'House'), ('House', 'of'), ('of', 'Representatives'), ('Representatives', ':')]
# [nltk_data] Downloading package inaugural to C:\Users\Computers
# [nltk_data]     Way\AppData\Roaming\nltk_data...
# [nltk_data]   Package inaugural is already up-to-date!
