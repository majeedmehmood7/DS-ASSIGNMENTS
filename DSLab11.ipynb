# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Advertising.csv")
data.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
plt.scatter(data.TV, data.Sales, color='blue', label='TV', alpha=0.5)
plt.scatter(data.Radio, data.Sales, color='red', label='radio',
alpha=0.5)
plt.scatter(data.Newspaper, data.Sales, color='green',
label='newspaper', alpha=0.5)
plt.legend(loc="lower right")
plt.title("Sales vs. Advertising")
plt.xlabel("Advertising [1000 $]")
plt.ylabel("Sales [Thousands of units]")
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-8c7bcbfdee84> in <cell line: 1>()
# ----> 1 plt.scatter(data.TV, data.Sales, color='blue', label='TV', alpha=0.5)
#       2 plt.scatter(data.Radio, data.Sales, color='red', label='radio',
#       3 alpha=0.5)
#       4 plt.scatter(data.Newspaper, data.Sales, color='green',
#       5 label='newspaper', alpha=0.5)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Sales'

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(data.drop('Sales', axis=1), data.Sales)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-72c5ee913907> in <cell line: 3>()
#       1 from sklearn.linear_model import LinearRegression
#       2 model = LinearRegression()
# ----> 3 model.fit(data.drop('Sales', axis=1), data.Sales)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503         for axis, labels in axes.items():
#    4504             if labels is not None:
# -> 4505                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4506
#    4507         if inplace:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4544                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4545             else:
# -> 4546                 new_axis = axis.drop(labels, errors=errors)
#    4547             indexer = axis.get_indexer(new_axis)
#    4548
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6932         if mask.any():
#    6933             if errors != "ignore":
# -> 6934                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6935             indexer = indexer[~mask]
#    6936         return self.delete(indexer)
#
# KeyError: "['Sales'] not found in axis"

# %%
# Importing required libraries
import pandas as pd
import statsmodels.formula.api as sm
# Loading data - You can give the complete path to your data here
ad = pd.read_csv("Advertising.csv")
# Fitting the OLS on data
model = sm.ols('Sales ~ TV + Radio + Newspaper', ad).fit()
print(model.params)
# Out:
# Intercept    2.938889
# TV           0.045765
# Radio        0.188530
# Newspaper   -0.001037
# dtype: float64

# %%
data.corr()
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.054809   0.056648  0.782224
# Radio      0.054809  1.000000   0.354104  0.576223
# Newspaper  0.056648  0.354104   1.000000  0.228299
# Sales      0.782224  0.576223   0.228299  1.000000

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.imshow(ad.corr(), cmap=plt.cm.GnBu,
interpolation='nearest',data=True)
plt.colorbar()
tick_marks = [i for i in range(len(data.columns))]
plt.xticks(tick_marks, data.columns, rotation=45)
plt.yticks(tick_marks, data.columns, rotation=45)
# Out:
# ([<matplotlib.axis.YTick at 0x7f8f53036f50>,
#   <matplotlib.axis.YTick at 0x7f8f530368f0>,
#   <matplotlib.axis.YTick at 0x7f8f53035900>,
#   <matplotlib.axis.YTick at 0x7f8f52ef5210>],
#  [Text(0, 0, 'TV'),
#   Text(0, 1, 'Radio'),
#   Text(0, 2, 'Newspaper'),
#   Text(0, 3, 'Sales')])

# %%
print(model.summary2())
# Out:
#                  Results: Ordinary least squares
# =================================================================
# Model:              OLS              Adj. R-squared:     0.896
# Dependent Variable: Sales            AIC:                780.3622
# Date:               2023-05-29 19:34 BIC:                793.5555
# No. Observations:   200              Log-Likelihood:     -386.18
# Df Model:           3                F-statistic:        570.3
# Df Residuals:       196              Prob (F-statistic): 1.58e-96
# R-squared:          0.897            Scale:              2.8409
# ------------------------------------------------------------------
#                 Coef.   Std.Err.     t     P>|t|    [0.025  0.975]
# ------------------------------------------------------------------
# Intercept       2.9389    0.3119   9.4223  0.0000   2.3238  3.5540
# TV              0.0458    0.0014  32.8086  0.0000   0.0430  0.0485
# Radio           0.1885    0.0086  21.8935  0.0000   0.1715  0.2055
# Newspaper      -0.0010    0.0059  -0.1767  0.8599  -0.0126  0.0105
# -----------------------------------------------------------------
# Omnibus:             60.414       Durbin-Watson:          2.084
# Prob(Omnibus):       0.000        Jarque-Bera (JB):       151.241
# Skew:                -1.327       Prob(JB):               0.000
# Kurtosis:            6.332        Condition No.:          454
# =================================================================

# %%
# Defining a function to evaluate a model
def evaluateModel(model):
  print("RSS = ", ((ad.Sales - model.predict())**2).sum())
  print("R2 = ", model.rsquared)

# For TV
model_TV = sm.ols('Sales ~ TV', data).fit()
print("model_TV")
evaluateModel(model_TV)
print("------------")
# For radio
model_radio = sm.ols('Sales ~ Radio', data).fit()
print("model_radio")
evaluateModel(model_radio)
print("------------")
# For newspaper
model_newspaper = sm.ols('Sales ~ Newspaper', data).fit()
print("model_newspaper")
evaluateModel(model_newspaper)
print("------------")
# For TV & newspaper
model_TV_newspaper = sm.ols('Sales ~ TV + Newspaper', data).fit()
print("model_TV_newspaper")
evaluateModel(model_TV_newspaper)
print("------------")
# For TV, radio & newspaper
model_all = sm.ols('Sales ~ TV + Radio + Newspaper', data).fit()
print("model_all")
evaluateModel(model_all)
print("------------")
model_all
# Out:
# model_TV
# RSS =  2102.530583131351
# R2 =  0.611875050850071
# ------------
# model_radio
# RSS =  3618.479549025087
# R2 =  0.33203245544529547
# ------------
# model_newspaper
# RSS =  5134.804544111939
# R2 =  0.05212044544430516
# ------------
# model_TV_newspaper
# RSS =  1918.5618118968277
# R2 =  0.6458354938293271
# ------------
# model_all
# RSS =  556.8252629021872
# R2 =  0.8972106381789522
# ------------

# %%
import pandas as pd
import numpy as np
from mpl_toolkits import mplot3d
# %matplotlib inline
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
## Loading data in ad variable
ad = pd.read_csv("/content/Advertising.csv")
ad.drop("Unnamed: 0", axis =1,inplace=True)
fig = plt.figure(figsize=(12,10))
ax = fig.add_subplot(211, projection='3d')
fig.suptitle('Regression: Sales ~ TV & radio Advertising')
# Defining z function (or sales in terms of TV and radio)
def z_function(x,y):
  return (2.938889 + (0.045765*y) + (0.188530*x))

X, Y = np.meshgrid(range(0,50,2),range(0,300,10))
Z = z_function(X, Y)
## Creating Wireframe
ax.plot_wireframe(X, Y, Z, color='black')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
## Creating Surface plot
ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap='winter',
edgecolor='black', alpha=0.8)
## Adding Scatter Plot
ax.scatter(ad.Radio, ad.TV, ad.Sales, c='red', s=25)
## Adding labels
ax.set_xlabel('Radio')
ax.set_ylabel('TV')
ax.set_zlabel('Sales')
ax.text(0,150,1, '@DataScienceWithSan')
## Rotating for better view
ax.view_init(10,30)

# %% [markdown]
# # **TASK 02**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('data1.csv')
data
# Out:
#     age  experience  income
# 0    25           1   30450
# 1    30           3   35670
# 2    47           2   31580
# 3    32           5   40130
# 4    43          10   47830
# 5    51           7   41630
# 6    28           5   41340
# 7    33           4   37650
# 8    37           5   40250
# 9    39           8   45150
# 10   29           1   27840
# 11   47           9   46110
# 12   54           5   36720
# 13   51           4   34800
# 14   44          12   51300
# 15   41           6   38900
# 16   58          17   63600
# 17   23           1   30870
# 18   44           9   44190
# 19   37          10   48700

# %%
plt.scatter(data.age, data.income, color='blue', label='TV', alpha=0.5)
plt.scatter(data.experience, data.income, color='red', label='radio',
alpha=0.5)
plt.legend(loc="lower right")
plt.title("Age & Experience vs. Income")
plt.xlabel("Age & Experience")
plt.ylabel("Income [1000 $]")
plt.grid()
plt.show()

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(data.drop('income', axis=1), data.income)
# Out:
# LinearRegression()

# %%
# Importing required libraries
import pandas as pd
import statsmodels.formula.api as sm
# Loading data - You can give the complete path to your data here
ad = pd.read_csv("data1.csv")
# Fitting the OLS on data
model = sm.ols('income ~ age + experience', ad).fit()
print(model.params)
# Out:
# Intercept     31261.689854
# age             -99.195355
# experience     2162.404192
# dtype: float64

# %%
data.corr()
# Out:
#                  age  experience    income
# age         1.000000    0.615165  0.532204
# experience  0.615165    1.000000  0.984227
# income      0.532204    0.984227  1.000000

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.imshow(ad.corr(), cmap=plt.cm.GnBu,
interpolation='nearest',data=True)
plt.colorbar()
tick_marks = [i for i in range(len(data.columns))]
plt.xticks(tick_marks, data.columns, rotation=45)
plt.yticks(tick_marks, data.columns, rotation=45)
# Out:
# ([<matplotlib.axis.YTick at 0x7efe2aba5b10>,
#   <matplotlib.axis.YTick at 0x7efe2aba54b0>,
#   <matplotlib.axis.YTick at 0x7efe2aba44f0>],
#  [Text(0, 0, 'age'), Text(0, 1, 'experience'), Text(0, 2, 'income')])

# %%
print(model.summary2())
# Out:
#                   Results: Ordinary least squares
# ====================================================================
# Model:               OLS              Adj. R-squared:     0.975
# Dependent Variable:  income           AIC:                347.6206
# Date:                2023-05-31 16:21 BIC:                350.6078
# No. Observations:    20               Log-Likelihood:     -170.81
# Df Model:            2                F-statistic:        366.5
# Df Residuals:        17               Prob (F-statistic): 1.05e-14
# R-squared:           0.977            Scale:              1.8043e+06
# --------------------------------------------------------------------
#              Coef.     Std.Err.    t    P>|t|    [0.025     0.975]
# --------------------------------------------------------------------
# Intercept  31261.6899 1306.4366 23.9290 0.0000 28505.3496 34018.0301
# age          -99.1954   38.9786 -2.5449 0.0209  -181.4331   -16.9576
# experience  2162.4042   94.7698 22.8174 0.0000  1962.4573  2362.3510
# --------------------------------------------------------------------
# Omnibus:                0.799         Durbin-Watson:           1.628
# Prob(Omnibus):          0.671         Jarque-Bera (JB):        0.695
# Skew:                   -0.404        Prob(JB):                0.707
# Kurtosis:               2.575         Condition No.:           180
# ====================================================================

# %%
# Defining a function to evaluate a model
def evaluateModel(model):
  print("RSS = ", ((ad.income - model.predict())**2).sum())
  print("R2 = ", model.rsquared)

# For Age
model_AGE = sm.ols('income ~ age', data).fit()
print("model_AGE")
evaluateModel(model_AGE)
print("------------")
# For Experience
model_experience = sm.ols('income ~ experience', data).fit()
print("model_experience")
evaluateModel(model_experience)
print("------------")

# For AGE, EXPERIENCE
#model_all = sm.ols('income ~ age + experience', data).fit()
#print("model_all")
#evaluateModel(model_all)
#print("------------")
#model_all
# Out:
# model_AGE
# RSS =  970042016.2466303
# R2 =  0.2832414556436763
# ------------
# model_experience
# RSS =  42357777.66089109
# R2 =  0.9687020783121727
# ------------

# %%
# For AGE, EXPERIENCE
model_age_experience = sm.ols('income ~ age + experience', data).fit()
print("model_age_experience")
evaluateModel(model_age_experience)
print("------------")
model_age_experience
# Out:
# model_age_experience
# RSS =  30672679.574283592
# R2 =  0.9773361310180797
# ------------

# %%
import statsmodels.api as sm1

new_data = pd.DataFrame({'age': [25], 'experience': [1]})

# Add a constant column to the new data
new_data = sm1.add_constant(new_data)
# Make predictions on the new data point
predictions = model_age_experience.predict(new_data)

print("Predictions:", predictions)
# Out:
# Predictions: 0    30944.210159
# dtype: float64

# %%
import pandas as pd
import numpy as np
from mpl_toolkits import mplot3d
# %matplotlib inline
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
## Loading data in ad variable
ad = pd.read_csv("/content/data1.csv")
fig = plt.figure(figsize=(12,10))
ax = fig.add_subplot(211, projection='3d')
fig.suptitle('Regression: income ~ age & experience')
# Defining z function (or sales in terms of Age and Experience)
def z_function(x,y):
  return (2.938889 + (0.045765*y) + (0.188530*x))

X, Y = np.meshgrid(range(0,50,2),range(0,300,10))
Z = z_function(X, Y)
## Creating Wireframe
ax.plot_wireframe(X, Y, Z, color='black')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
## Creating Surface plot
ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap='winter',
edgecolor='black', alpha=0.8)
## Adding Scatter Plot
ax.scatter(ad.age, ad.experience, ad.income, c='red', s=25)
## Adding labels
ax.set_xlabel('Age')
ax.set_ylabel('Experience')
ax.set_zlabel('Income')
ax.text(0,150,1, '@DataScienceWithSan')
## Rotating for better view
ax.view_init(10,30)
